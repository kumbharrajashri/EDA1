# %%
import numpy as np
import pandas as pd

# %%
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
df_test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
df_train.groupby('Survived')['PassengerId'].count()
# Out:
# Survived
# 0    549
# 1    342
# Name: PassengerId, dtype: int64

# %%
sns.countplot(x='Survived', data=df_train);

# %%
print(df_train.Survived.sum()/df_train.Survived.count())
# Out:
# 0.3838383838383838

# %%
df_train.groupby(['Survived','Sex'])['Survived'].count()
# Out:
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# Name: Survived, dtype: int64

# %%
sns.catplot(x='Sex', col='Survived', kind='count', data=df_train);

# %%
#f, ax = plt.subplots(figsize=(5,4))
sns.barplot(x='Sex', y="Survived",  data=df_train);

# %%
print("% of women survived: " , df_train[df_train.Sex == 'female'].Survived.sum()/df_train[df_train.Sex == 'female'].Survived.count())
print("% of men survived:   " , df_train[df_train.Sex == 'male'].Survived.sum()/df_train[df_train.Sex == 'male'].Survived.count())
# Out:
# % of women survived:  0.7420382165605095
# % of men survived:    0.18890814558058924

# %%
f, ax = plt.subplots(figsize=(11,5))
sns.boxplot(x="Sex", y="Age", hue="Survived", data=df_train);

# %%
f,ax=plt.subplots(1,2,figsize=(16,7))
df_train['Survived'][df_train['Sex']=='male'].value_counts().plot.pie(explode=[0,0.2],autopct='%1.1f%%',ax=ax[0],shadow=True)
df_train['Survived'][df_train['Sex']=='female'].value_counts().plot.pie(explode=[0,0.2],autopct='%1.1f%%',ax=ax[1],shadow=True)
ax[0].set_title('Survived (male)')
ax[1].set_title('Survived (female)')

plt.show()

# %%
pd.crosstab(df_train.Pclass, df_train.Survived, margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style type="text/css">
# #T_f58a1_row0_col0, #T_f58a1_row1_col1, #T_f58a1_row1_col2 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_f58a1_row0_col1 {
#   background-color: #ffce00;
#   color: #000000;
# }
# #T_f58a1_row0_col2 {
#   background-color: #fff400;
#   color: #000000;
# }
# #T_f58a1_row1_col0 {
#   background-color: #fff600;
#   color: #000000;
# }
# #T_f58a1_row2_col0 {
#   background-color: #ff6000;
#   color: #f1f1f1;
# }
# #T_f58a1_row2_col1 {
#   background-color: #ffdf00;
#   color: #000000;
# }
# #T_f58a1_row2_col2 {
#   background-color: #ff9000;
#   color: #000000;
# }
# #T_f58a1_row3_col0, #T_f58a1_row3_col1, #T_f58a1_row3_col2 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f58a1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_f58a1_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f58a1_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_f58a1_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f58a1_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_f58a1_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_f58a1_row0_col1" class="data row0 col1" >136</td>
#       <td id="T_f58a1_row0_col2" class="data row0 col2" >216</td>
#     </tr>
#     <tr>
#       <th id="T_f58a1_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_f58a1_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_f58a1_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_f58a1_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_f58a1_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_f58a1_row2_col0" class="data row2 col0" >372</td>
#       <td id="T_f58a1_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_f58a1_row2_col2" class="data row2 col2" >491</td>
#     </tr>
#     <tr>
#       <th id="T_f58a1_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_f58a1_row3_col0" class="data row3 col0" >549</td>
#       <td id="T_f58a1_row3_col1" class="data row3 col1" >342</td>
#       <td id="T_f58a1_row3_col2" class="data row3 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("% of survivals in") 
print("Pclass=1 : ", df_train.Survived[df_train.Pclass == 1].sum()/df_train[df_train.Pclass == 1].Survived.count())
print("Pclass=2 : ", df_train.Survived[df_train.Pclass == 2].sum()/df_train[df_train.Pclass == 2].Survived.count())
print("Pclass=3 : ", df_train.Survived[df_train.Pclass == 3].sum()/df_train[df_train.Pclass == 3].Survived.count())
# Out:
# % of survivals in
# Pclass=1 :  0.6296296296296297
# Pclass=2 :  0.47282608695652173
# Pclass=3 :  0.24236252545824846

# %%
sns.barplot(x="Pclass", y="Survived", data=df_train);

# %%
sns.catplot('Pclass','Survived', kind='point', data=df_train);
# Out:
# C:\Users\Rajashri\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot(x="Pclass", y="Survived",hue="Sex", data=df_train);

# %%
pd.crosstab([df_train.Sex, df_train.Survived], df_train.Pclass, margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style type="text/css">
# #T_51e79_row0_col0, #T_51e79_row0_col1, #T_51e79_row0_col3, #T_51e79_row3_col2 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_51e79_row0_col2, #T_51e79_row1_col2 {
#   background-color: #fff100;
#   color: #000000;
# }
# #T_51e79_row1_col0 {
#   background-color: #ff9600;
#   color: #000000;
# }
# #T_51e79_row1_col1 {
#   background-color: #ffa300;
#   color: #000000;
# }
# #T_51e79_row1_col3 {
#   background-color: #ffcf00;
#   color: #000000;
# }
# #T_51e79_row2_col0 {
#   background-color: #ffa700;
#   color: #000000;
# }
# #T_51e79_row2_col1, #T_51e79_row2_col3 {
#   background-color: #ff8500;
#   color: #f1f1f1;
# }
# #T_51e79_row2_col2 {
#   background-color: #ff6e00;
#   color: #f1f1f1;
# }
# #T_51e79_row3_col0 {
#   background-color: #ffcd00;
#   color: #000000;
# }
# #T_51e79_row3_col1 {
#   background-color: #fff000;
#   color: #000000;
# }
# #T_51e79_row3_col3 {
#   background-color: #fff700;
#   color: #000000;
# }
# #T_51e79_row4_col0, #T_51e79_row4_col1, #T_51e79_row4_col2, #T_51e79_row4_col3 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_51e79">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_51e79_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_51e79_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_51e79_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_51e79_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="index_name level1" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51e79_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#       <th id="T_51e79_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_51e79_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_51e79_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_51e79_row0_col2" class="data row0 col2" >72</td>
#       <td id="T_51e79_row0_col3" class="data row0 col3" >81</td>
#     </tr>
#     <tr>
#       <th id="T_51e79_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_51e79_row1_col0" class="data row1 col0" >91</td>
#       <td id="T_51e79_row1_col1" class="data row1 col1" >70</td>
#       <td id="T_51e79_row1_col2" class="data row1 col2" >72</td>
#       <td id="T_51e79_row1_col3" class="data row1 col3" >233</td>
#     </tr>
#     <tr>
#       <th id="T_51e79_level0_row2" class="row_heading level0 row2" rowspan="2">male</th>
#       <th id="T_51e79_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_51e79_row2_col0" class="data row2 col0" >77</td>
#       <td id="T_51e79_row2_col1" class="data row2 col1" >91</td>
#       <td id="T_51e79_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_51e79_row2_col3" class="data row2 col3" >468</td>
#     </tr>
#     <tr>
#       <th id="T_51e79_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_51e79_row3_col0" class="data row3 col0" >45</td>
#       <td id="T_51e79_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_51e79_row3_col2" class="data row3 col2" >47</td>
#       <td id="T_51e79_row3_col3" class="data row3 col3" >109</td>
#     </tr>
#     <tr>
#       <th id="T_51e79_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_51e79_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_51e79_row4_col0" class="data row4 col0" >216</td>
#       <td id="T_51e79_row4_col1" class="data row4 col1" >184</td>
#       <td id="T_51e79_row4_col2" class="data row4 col2" >491</td>
#       <td id="T_51e79_row4_col3" class="data row4 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.catplot('Pclass','Survived',hue='Sex', kind='point', data=df_train);
# Out:
# C:\Users\Rajashri\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot(x='Survived', col='Embarked', kind='count', data=df_train);

# %%
sns.catplot('Embarked','Survived', kind='point', data=df_train);
# Out:
# C:\Users\Rajashri\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot('Embarked','Survived', hue= 'Sex', kind='point', data=df_train);
# Out:
# C:\Users\Rajashri\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot('Embarked','Survived', col='Pclass', hue= 'Sex', kind='point', data=df_train);
# Out:
# C:\Users\Rajashri\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pd.crosstab([df_train.Survived], [df_train.Sex, df_train.Pclass, df_train.Embarked], margins=True)
# Out:
# Sex      female                              male                            \
# Pclass        1         2          3            1          2          3
# Embarked      C  Q   S  C  Q   S   C   Q   S    C  Q   S   C  Q   S   C   Q
# Survived
# 0             1  0   2  0  0   6   8   9  55   25  1  51   8  1  82  33  36
# 1            42  1  46  7  2  61  15  24  33   17  0  28   2  0  15  10   3
# All          43  1  48  7  2  67  23  33  88   42  1  79  10  1  97  43  39
#
# Sex            All
# Pclass
# Embarked    S
# Survived
# 0         231  549
# 1          34  340
# All       265  889

# %%
sns.barplot(x="SibSp", y="Survived", data=df_train);

# %%
sns.barplot(x="Parch", y="Survived", data=df_train);

# %%
survived = df_train.loc[df_train['Survived']==1,"Age"].dropna()
sns.distplot(survived)
plt.title("Survived");
# Out:
# C:\Users\Rajashri\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
not_survived = df_train.loc[df_train['Survived']==0,"Age"].dropna()
sns.distplot(not_survived)
plt.title("Not Survived");
# Out:
# C:\Users\Rajashri\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.pairplot(df_train.dropna());

# %%
figbi, axesbi = plt.subplots(2, 4, figsize=(16, 10))
df_train.groupby('Pclass')['Survived'].mean().plot(kind='barh',ax=axesbi[0,0],xlim=[0,1])
df_train.groupby('SibSp')['Survived'].mean().plot(kind='barh',ax=axesbi[0,1],xlim=[0,1])
df_train.groupby('Parch')['Survived'].mean().plot(kind='barh',ax=axesbi[0,2],xlim=[0,1])
df_train.groupby('Sex')['Survived'].mean().plot(kind='barh',ax=axesbi[0,3],xlim=[0,1])
df_train.groupby('Embarked')['Survived'].mean().plot(kind='barh',ax=axesbi[1,0],xlim=[0,1])
sns.boxplot(x="Survived", y="Age", data=df_train,ax=axesbi[1,1])
sns.boxplot(x="Survived", y="Fare", data=df_train,ax=axesbi[1,2])
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Fare'>

# %%
sns.catplot(x='Sex', y='Age', data=df_train, kind='box', hue='Pclass')

# %%
# Explore the correlation between different features
correlation_matrix = df_train.dropna().corr()
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix')
plt.show()

# %%
# model 3
df_test['Survived'] = 0
# all women survived
df_test.loc[ (df_test.Sex == 'female'), 'Survived'] = 1
# except for those in Pclass 3 and embarked in S
df_test.loc[ (df_test.Sex == 'female') & (df_test.Pclass == 3) & (df_test.Embarked == 'S') , 'Survived'] = 0
#df_test[['PassengerId', 'Survived']].to_csv('embarked_pclass_sex.csv', index=False)

# %%
for df in [df_train, df_test]:
    df['Age_bin']=np.nan
    for i in range(8,0,-1):
        df.loc[ df['Age'] <= i*10, 'Age_bin'] = i

# %%
print(df_train[['Age' , 'Age_bin']].head(10))
# Out:
#     Age  Age_bin
# 0  22.0      3.0
# 1  38.0      4.0
# 2  26.0      3.0
# 3  35.0      4.0
# 4  35.0      4.0
# 5   NaN      NaN
# 6  54.0      6.0
# 7   2.0      1.0
# 8  27.0      3.0
# 9  14.0      2.0

# %%
sns.catplot('Age_bin','Survived',hue='Sex',kind='point',data=df_train);
# Out:
# C:\Users\Rajashri\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot('Age_bin','Survived', col='Pclass' , row = 'Sex', kind='point', data=df_train);
# Out:
# C:\Users\Rajashri\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pd.crosstab([df_train.Sex, df_train.Survived], [df_train.Age_bin, df_train.Pclass], margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style type="text/css">
# #T_01439_row0_col0, #T_01439_row1_col20, #T_01439_row3_col19, #T_01439_row3_col21 {
#   background-color: #ffaa00;
#   color: #000000;
# }
# #T_01439_row0_col1, #T_01439_row0_col3, #T_01439_row0_col4, #T_01439_row0_col6, #T_01439_row0_col9, #T_01439_row0_col10, #T_01439_row0_col12, #T_01439_row0_col13, #T_01439_row0_col15, #T_01439_row0_col17, #T_01439_row0_col18, #T_01439_row0_col19, #T_01439_row0_col20, #T_01439_row0_col21, #T_01439_row0_col22, #T_01439_row0_col23, #T_01439_row1_col0, #T_01439_row1_col11, #T_01439_row1_col14, #T_01439_row1_col17, #T_01439_row1_col19, #T_01439_row1_col21, #T_01439_row1_col22, #T_01439_row2_col0, #T_01439_row2_col1, #T_01439_row3_col2, #T_01439_row3_col5, #T_01439_row3_col7, #T_01439_row3_col8, #T_01439_row3_col13, #T_01439_row3_col16, #T_01439_row3_col17, #T_01439_row3_col18, #T_01439_row3_col20, #T_01439_row3_col22 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_01439_row0_col2, #T_01439_row0_col16, #T_01439_row1_col2, #T_01439_row1_col5 {
#   background-color: #ffea00;
#   color: #000000;
# }
# #T_01439_row0_col5, #T_01439_row3_col14 {
#   background-color: #ffee00;
#   color: #000000;
# }
# #T_01439_row0_col7, #T_01439_row3_col10 {
#   background-color: #fff300;
#   color: #000000;
# }
# #T_01439_row0_col8, #T_01439_row1_col8, #T_01439_row3_col11 {
#   background-color: #fffb00;
#   color: #000000;
# }
# #T_01439_row0_col11 {
#   background-color: #fff700;
#   color: #000000;
# }
# #T_01439_row0_col14 {
#   background-color: #ffbb00;
#   color: #000000;
# }
# #T_01439_row1_col1 {
#   background-color: #ff8700;
#   color: #f1f1f1;
# }
# #T_01439_row1_col3 {
#   background-color: #ff4700;
#   color: #f1f1f1;
# }
# #T_01439_row1_col4, #T_01439_row1_col13 {
#   background-color: #ff8e00;
#   color: #f1f1f1;
# }
# #T_01439_row1_col6 {
#   background-color: #ff8300;
#   color: #f1f1f1;
# }
# #T_01439_row1_col7 {
#   background-color: #ff9700;
#   color: #000000;
# }
# #T_01439_row1_col9 {
#   background-color: #ff8200;
#   color: #f1f1f1;
# }
# #T_01439_row1_col10 {
#   background-color: #ffa400;
#   color: #000000;
# }
# #T_01439_row1_col12 {
#   background-color: #ffb100;
#   color: #000000;
# }
# #T_01439_row1_col15 {
#   background-color: #ff8f00;
#   color: #000000;
# }
# #T_01439_row1_col16, #T_01439_row2_col2, #T_01439_row2_col3 {
#   background-color: #ffd500;
#   color: #000000;
# }
# #T_01439_row1_col18 {
#   background-color: #ffd100;
#   color: #000000;
# }
# #T_01439_row1_col23, #T_01439_row3_col6 {
#   background-color: #ffcb00;
#   color: #000000;
# }
# #T_01439_row2_col4 {
#   background-color: #ff7f00;
#   color: #f1f1f1;
# }
# #T_01439_row2_col5 {
#   background-color: #ff7100;
#   color: #f1f1f1;
# }
# #T_01439_row2_col6 {
#   background-color: #ffc400;
#   color: #000000;
# }
# #T_01439_row2_col7 {
#   background-color: #ff7500;
#   color: #f1f1f1;
# }
# #T_01439_row2_col8 {
#   background-color: #ff6600;
#   color: #f1f1f1;
# }
# #T_01439_row2_col9 {
#   background-color: #ffc100;
#   color: #000000;
# }
# #T_01439_row2_col10 {
#   background-color: #ff7900;
#   color: #f1f1f1;
# }
# #T_01439_row2_col11 {
#   background-color: #ff5e00;
#   color: #f1f1f1;
# }
# #T_01439_row2_col12, #T_01439_row2_col13 {
#   background-color: #ff9c00;
#   color: #000000;
# }
# #T_01439_row2_col14, #T_01439_row2_col19, #T_01439_row2_col20, #T_01439_row2_col21, #T_01439_row3_col0 {
#   background-color: #ff5500;
#   color: #f1f1f1;
# }
# #T_01439_row2_col15 {
#   background-color: #ff9900;
#   color: #000000;
# }
# #T_01439_row2_col16 {
#   background-color: #ff3f00;
#   color: #f1f1f1;
# }
# #T_01439_row2_col17, #T_01439_row2_col22, #T_01439_row4_col0, #T_01439_row4_col1, #T_01439_row4_col2, #T_01439_row4_col3, #T_01439_row4_col4, #T_01439_row4_col5, #T_01439_row4_col6, #T_01439_row4_col7, #T_01439_row4_col8, #T_01439_row4_col9, #T_01439_row4_col10, #T_01439_row4_col11, #T_01439_row4_col12, #T_01439_row4_col13, #T_01439_row4_col14, #T_01439_row4_col15, #T_01439_row4_col16, #T_01439_row4_col17, #T_01439_row4_col18, #T_01439_row4_col19, #T_01439_row4_col20, #T_01439_row4_col21, #T_01439_row4_col22, #T_01439_row4_col23 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_01439_row2_col18 {
#   background-color: #ff2e00;
#   color: #f1f1f1;
# }
# #T_01439_row2_col23 {
#   background-color: #ff8b00;
#   color: #f1f1f1;
# }
# #T_01439_row3_col1 {
#   background-color: #ff7800;
#   color: #f1f1f1;
# }
# #T_01439_row3_col3 {
#   background-color: #ffe300;
#   color: #000000;
# }
# #T_01439_row3_col4 {
#   background-color: #fff100;
#   color: #000000;
# }
# #T_01439_row3_col9 {
#   background-color: #ffbc00;
#   color: #000000;
# }
# #T_01439_row3_col12 {
#   background-color: #ffc700;
#   color: #000000;
# }
# #T_01439_row3_col15 {
#   background-color: #ffd700;
#   color: #000000;
# }
# #T_01439_row3_col23 {
#   background-color: #fff400;
#   color: #000000;
# }
# </style>
# <table id="T_01439">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Age_bin</th>
#       <th id="T_01439_level0_col0" class="col_heading level0 col0" colspan="3">1.000000</th>
#       <th id="T_01439_level0_col3" class="col_heading level0 col3" colspan="3">2.000000</th>
#       <th id="T_01439_level0_col6" class="col_heading level0 col6" colspan="3">3.000000</th>
#       <th id="T_01439_level0_col9" class="col_heading level0 col9" colspan="3">4.000000</th>
#       <th id="T_01439_level0_col12" class="col_heading level0 col12" colspan="3">5.000000</th>
#       <th id="T_01439_level0_col15" class="col_heading level0 col15" colspan="3">6.000000</th>
#       <th id="T_01439_level0_col18" class="col_heading level0 col18" colspan="3">7.000000</th>
#       <th id="T_01439_level0_col21" class="col_heading level0 col21" colspan="2">8.000000</th>
#       <th id="T_01439_level0_col23" class="col_heading level0 col23" >All</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Pclass</th>
#       <th id="T_01439_level1_col0" class="col_heading level1 col0" >1</th>
#       <th id="T_01439_level1_col1" class="col_heading level1 col1" >2</th>
#       <th id="T_01439_level1_col2" class="col_heading level1 col2" >3</th>
#       <th id="T_01439_level1_col3" class="col_heading level1 col3" >1</th>
#       <th id="T_01439_level1_col4" class="col_heading level1 col4" >2</th>
#       <th id="T_01439_level1_col5" class="col_heading level1 col5" >3</th>
#       <th id="T_01439_level1_col6" class="col_heading level1 col6" >1</th>
#       <th id="T_01439_level1_col7" class="col_heading level1 col7" >2</th>
#       <th id="T_01439_level1_col8" class="col_heading level1 col8" >3</th>
#       <th id="T_01439_level1_col9" class="col_heading level1 col9" >1</th>
#       <th id="T_01439_level1_col10" class="col_heading level1 col10" >2</th>
#       <th id="T_01439_level1_col11" class="col_heading level1 col11" >3</th>
#       <th id="T_01439_level1_col12" class="col_heading level1 col12" >1</th>
#       <th id="T_01439_level1_col13" class="col_heading level1 col13" >2</th>
#       <th id="T_01439_level1_col14" class="col_heading level1 col14" >3</th>
#       <th id="T_01439_level1_col15" class="col_heading level1 col15" >1</th>
#       <th id="T_01439_level1_col16" class="col_heading level1 col16" >2</th>
#       <th id="T_01439_level1_col17" class="col_heading level1 col17" >3</th>
#       <th id="T_01439_level1_col18" class="col_heading level1 col18" >1</th>
#       <th id="T_01439_level1_col19" class="col_heading level1 col19" >2</th>
#       <th id="T_01439_level1_col20" class="col_heading level1 col20" >3</th>
#       <th id="T_01439_level1_col21" class="col_heading level1 col21" >1</th>
#       <th id="T_01439_level1_col22" class="col_heading level1 col22" >3</th>
#       <th id="T_01439_level1_col23" class="col_heading level1 col23" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="index_name level1" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th cla
